# %% [markdown]
# Section D: Q1. Which department appears strongest in the dataset and why?
#
#
# ---
# Ans:
# 1. The Computer Department appears to be the strongest in the dataset beacuse the top performer is from Computer Department that is Gauri and she has scored 92.97.
# 2. The average readiness score of COmputer Department is the highest across all departments.

# %% [markdown]
# Q2. Which students need immediate academic support and what signals show that?
#
# ---
# Ans: The students needing immeditate academic support are:
# 1. Divya from IT
# 2. Harshada from IT
#
# These students need immediate academic support since their readiness scores are the lowest in the dataset.

# %% [markdown]
# Q3. What is one limitation of this small dataset?
#
# ---
# Ans: Limitations of small datasets:
# 1. Number of comparison appears to be less as compared to large datasets.
# 2. Rare edge cases may not appear in the small datasets.
# 3. Models may meorize specific cases rather than learning patterns.

# %% [markdown]
# Q4. What extra columns would make the analysis more useful for the internship team?
#
# ---
# Ans: The columns which will make the analysis more useful are:
# 1. Skills developed.
# 2. Last semester percentage
# 3. Behavioral ranks.
